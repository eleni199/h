# %% [markdown]
# <a href="https://colab.research.google.com/github/eleni199/h/blob/main/eleni199/h/follium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.8/dist-packages (0.12.1.post1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.8/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from folium) (1.21.6)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->folium) (2022.9.24)

# %%
import folium

# %%
mymap = folium.Map(location = [41.1282, 26.1814],
                   zoom_start = 12, 
                   tiles = 'openstreetmap')

# %%
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0307371027717092d1ef08ecec5800e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0307371027717092d1ef08ecec5800e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0307371027717092d1ef08ecec5800e = L.map(
#                 &quot;map_a0307371027717092d1ef08ecec5800e&quot;,
#                 {
#                     center: [41.1282, 26.1814],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cf1fc1c2cdcebfdb206d95f713fe27f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a0307371027717092d1ef08ecec5800e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[38.006481597445884, 21.28306693480314], zoom_start=7
                              
              )

tooltip = "Click Here For More Info"

marker = folium.Marker(
    location=[38.00648159992793, 21.28289528175436],
    popup="Λιμνοθάλασσες Κοτυχίου",
    tooltip=tooltip)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b42bdd3882d1cc702f8d598311aa0b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b42bdd3882d1cc702f8d598311aa0b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b42bdd3882d1cc702f8d598311aa0b6 = L.map(
#                 &quot;map_2b42bdd3882d1cc702f8d598311aa0b6&quot;,
#                 {
#                     center: [38.006481597445884, 21.28306693480314],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63734f9f7e9435d614728d994ef5870d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2b42bdd3882d1cc702f8d598311aa0b6);
#
#
#             var marker_29d754802330c8e29de4211e72d98a47 = L.marker(
#                 [38.00648159992793, 21.28289528175436],
#                 {}
#             ).addTo(map_2b42bdd3882d1cc702f8d598311aa0b6);
#
#
#         var popup_5e5cbb2b9998f1dbadd6b529577e877b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1026331a9caa1cb939cab8b74b15484c = $(`&lt;div id=&quot;html_1026331a9caa1cb939cab8b74b15484c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Λιμνοθάλασσες Κοτυχίου&lt;/div&gt;`)[0];
#             popup_5e5cbb2b9998f1dbadd6b529577e877b.setContent(html_1026331a9caa1cb939cab8b74b15484c);
#
#
#         marker_29d754802330c8e29de4211e72d98a47.bindPopup(popup_5e5cbb2b9998f1dbadd6b529577e877b)
#         ;
#
#
#
#
#             marker_29d754802330c8e29de4211e72d98a47.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# kotychi_beach's location
lat_kotychi = 38.015948900667816
lon_kotychi = 21.291135926007893
kotychi_icon = folium.Icon(icon='glass', color='blue', icon_color='white', prefix='glyphicon')
folium.Marker(
    location=[38.015610833153296, 21.2902775006116],
              icon=kotychi_icon,
              tooltip='More info here!',
              popup='all day open!'
             ).add_to(m)
m.zoom_start = 16
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a178b0ae0c3681c19f4d7a7c94a8083 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a178b0ae0c3681c19f4d7a7c94a8083&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a178b0ae0c3681c19f4d7a7c94a8083 = L.map(
#                 &quot;map_9a178b0ae0c3681c19f4d7a7c94a8083&quot;,
#                 {
#                     center: [38.37920552746681, 21.34399250286334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d7d74bd57a2677281446cdabc371e57 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a178b0ae0c3681c19f4d7a7c94a8083);
#
#
#             var marker_d9961bc8e513bff36df5953064efc590 = L.marker(
#                 [38.37920552746681, 21.34399250286334],
#                 {}
#             ).addTo(map_9a178b0ae0c3681c19f4d7a7c94a8083);
#
#
#         var popup_7726f86b8bc51706b7bcb4db9d707809 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4845021e5dcda0a5ce70cc9193fdbde9 = $(`&lt;div id=&quot;html_4845021e5dcda0a5ce70cc9193fdbde9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;limonothilasses_mesologgiou&lt;/div&gt;`)[0];
#             popup_7726f86b8bc51706b7bcb4db9d707809.setContent(html_4845021e5dcda0a5ce70cc9193fdbde9);
#
#
#         marker_d9961bc8e513bff36df5953064efc590.bindPopup(popup_7726f86b8bc51706b7bcb4db9d707809)
#         ;
#
#
#
#
#             marker_d9961bc8e513bff36df5953064efc590.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_83455b23af5258941546b3a2b214051f = L.marker(
#                 [38.015610833153296, 21.2902775006116],
#                 {}
#             ).addTo(map_9a178b0ae0c3681c19f4d7a7c94a8083);
#
#
#             var icon_8d13515bfdef8f4866a57cb4cc2eb671 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glass&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83455b23af5258941546b3a2b214051f.setIcon(icon_8d13515bfdef8f4866a57cb4cc2eb671);
#
#
#         var popup_70894cbbc576a20c3e1566c632504a4d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e926d75f7a8b962c7b5b1f5ecdfebef0 = $(`&lt;div id=&quot;html_e926d75f7a8b962c7b5b1f5ecdfebef0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;all day open!&lt;/div&gt;`)[0];
#             popup_70894cbbc576a20c3e1566c632504a4d.setContent(html_e926d75f7a8b962c7b5b1f5ecdfebef0);
#
#
#         marker_83455b23af5258941546b3a2b214051f.bindPopup(popup_70894cbbc576a20c3e1566c632504a4d)
#         ;
#
#
#
#
#             marker_83455b23af5258941546b3a2b214051f.bindTooltip(
#                 `&lt;div&gt;
#                      More info here!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[38.37920552746681, 21.34399250286334], zoom_start=7
                              
              )


tooltip = "Click Here For More Info"

marker = folium.Marker(
    location=[38.37920552746681, 21.34399250286334],
    popup="limonothilasses_mesologgiou",
    tooltip=tooltip)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a178b0ae0c3681c19f4d7a7c94a8083 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a178b0ae0c3681c19f4d7a7c94a8083&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a178b0ae0c3681c19f4d7a7c94a8083 = L.map(
#                 &quot;map_9a178b0ae0c3681c19f4d7a7c94a8083&quot;,
#                 {
#                     center: [38.37920552746681, 21.34399250286334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d7d74bd57a2677281446cdabc371e57 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a178b0ae0c3681c19f4d7a7c94a8083);
#
#
#             var marker_d9961bc8e513bff36df5953064efc590 = L.marker(
#                 [38.37920552746681, 21.34399250286334],
#                 {}
#             ).addTo(map_9a178b0ae0c3681c19f4d7a7c94a8083);
#
#
#         var popup_7726f86b8bc51706b7bcb4db9d707809 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4845021e5dcda0a5ce70cc9193fdbde9 = $(`&lt;div id=&quot;html_4845021e5dcda0a5ce70cc9193fdbde9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;limonothilasses_mesologgiou&lt;/div&gt;`)[0];
#             popup_7726f86b8bc51706b7bcb4db9d707809.setContent(html_4845021e5dcda0a5ce70cc9193fdbde9);
#
#
#         marker_d9961bc8e513bff36df5953064efc590.bindPopup(popup_7726f86b8bc51706b7bcb4db9d707809)
#         ;
#
#
#
#
#             marker_d9961bc8e513bff36df5953064efc590.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# agia_triada_church's location
lat_church = 38.39157089040406
lon_church = 21.3260586532404
church_icon = folium.Icon(icon='cross', color='blue', icon_color='white', prefix='glyphicon')
folium.Marker(
    location=[38.39157089040406, 21.32605865324041],
              icon=church_icon,
              tooltip='More info here!',
              popup='God is with you'
             ).add_to(m)
m.zoom_start = 16
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a178b0ae0c3681c19f4d7a7c94a8083 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a178b0ae0c3681c19f4d7a7c94a8083&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a178b0ae0c3681c19f4d7a7c94a8083 = L.map(
#                 &quot;map_9a178b0ae0c3681c19f4d7a7c94a8083&quot;,
#                 {
#                     center: [38.37920552746681, 21.34399250286334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d7d74bd57a2677281446cdabc371e57 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a178b0ae0c3681c19f4d7a7c94a8083);
#
#
#             var marker_d9961bc8e513bff36df5953064efc590 = L.marker(
#                 [38.37920552746681, 21.34399250286334],
#                 {}
#             ).addTo(map_9a178b0ae0c3681c19f4d7a7c94a8083);
#
#
#         var popup_7726f86b8bc51706b7bcb4db9d707809 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4845021e5dcda0a5ce70cc9193fdbde9 = $(`&lt;div id=&quot;html_4845021e5dcda0a5ce70cc9193fdbde9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;limonothilasses_mesologgiou&lt;/div&gt;`)[0];
#             popup_7726f86b8bc51706b7bcb4db9d707809.setContent(html_4845021e5dcda0a5ce70cc9193fdbde9);
#
#
#         marker_d9961bc8e513bff36df5953064efc590.bindPopup(popup_7726f86b8bc51706b7bcb4db9d707809)
#         ;
#
#
#
#
#             marker_d9961bc8e513bff36df5953064efc590.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_83455b23af5258941546b3a2b214051f = L.marker(
#                 [38.015610833153296, 21.2902775006116],
#                 {}
#             ).addTo(map_9a178b0ae0c3681c19f4d7a7c94a8083);
#
#
#             var icon_8d13515bfdef8f4866a57cb4cc2eb671 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glass&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83455b23af5258941546b3a2b214051f.setIcon(icon_8d13515bfdef8f4866a57cb4cc2eb671);
#
#
#         var popup_70894cbbc576a20c3e1566c632504a4d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e926d75f7a8b962c7b5b1f5ecdfebef0 = $(`&lt;div id=&quot;html_e926d75f7a8b962c7b5b1f5ecdfebef0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;all day open!&lt;/div&gt;`)[0];
#             popup_70894cbbc576a20c3e1566c632504a4d.setContent(html_e926d75f7a8b962c7b5b1f5ecdfebef0);
#
#
#         marker_83455b23af5258941546b3a2b214051f.bindPopup(popup_70894cbbc576a20c3e1566c632504a4d)
#         ;
#
#
#
#
#             marker_83455b23af5258941546b3a2b214051f.bindTooltip(
#                 `&lt;div&gt;
#                      More info here!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8476eb715f1b71e643c33fb9b189b484 = L.marker(
#                 [38.39157089040406, 21.32605865324041],
#                 {}
#             ).addTo(map_9a178b0ae0c3681c19f4d7a7c94a8083);
#
#
#             var icon_b59e0da6ec4a12200577a44a515f424a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cross&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8476eb715f1b71e643c33fb9b189b484.setIcon(icon_b59e0da6ec4a12200577a44a515f424a);
#
#
#         var popup_042ea48cc530ace6d495ea09004aa698 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_991678bf36c5727145f9600c0c8a6dc4 = $(`&lt;div id=&quot;html_991678bf36c5727145f9600c0c8a6dc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;God is with you&lt;/div&gt;`)[0];
#             popup_042ea48cc530ace6d495ea09004aa698.setContent(html_991678bf36c5727145f9600c0c8a6dc4);
#
#
#         marker_8476eb715f1b71e643c33fb9b189b484.bindPopup(popup_042ea48cc530ace6d495ea09004aa698)
#         ;
#
#
#
#
#             marker_8476eb715f1b71e643c33fb9b189b484.bindTooltip(
#                 `&lt;div&gt;
#                      More info here!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[38.956578908379335, 21.02247865318239], zoom_start=7
                              
              )
my_icon = folium.Icon(icon='star', color='black', icon_color='red') 

tooltip = "Click Here For More Info"

marker = folium.Marker(
    
    location=[38.956578908379335, 21.02247865318239],
    icon=my_icon,
    popup="Κόλπος Αμβρακικού",
    tooltip=tooltip)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3a0e46aa983429ba9bf8a62cf1eaac8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3a0e46aa983429ba9bf8a62cf1eaac8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3a0e46aa983429ba9bf8a62cf1eaac8 = L.map(
#                 &quot;map_c3a0e46aa983429ba9bf8a62cf1eaac8&quot;,
#                 {
#                     center: [38.956578908379335, 21.02247865318239],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6be77e3094d1bc5f764c78fb34b922cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c3a0e46aa983429ba9bf8a62cf1eaac8);
#
#
#             var marker_46a1f101b5d3bd90bb619e19b7792d8b = L.marker(
#                 [38.956578908379335, 21.02247865318239],
#                 {}
#             ).addTo(map_c3a0e46aa983429ba9bf8a62cf1eaac8);
#
#
#             var icon_79c63b3da253833c184cded13c6550af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_46a1f101b5d3bd90bb619e19b7792d8b.setIcon(icon_79c63b3da253833c184cded13c6550af);
#
#
#         var popup_e79ebca6ebcf0641840a0d834c9f696d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2aa9933209b187f3029c2672e74bb330 = $(`&lt;div id=&quot;html_2aa9933209b187f3029c2672e74bb330&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Κόλπος Αμβρακικού&lt;/div&gt;`)[0];
#             popup_e79ebca6ebcf0641840a0d834c9f696d.setContent(html_2aa9933209b187f3029c2672e74bb330);
#
#
#         marker_46a1f101b5d3bd90bb619e19b7792d8b.bindPopup(popup_e79ebca6ebcf0641840a0d834c9f696d)
#         ;
#
#
#
#
#             marker_46a1f101b5d3bd90bb619e19b7792d8b.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# managaia_hotel's location
lat_hotel = 38.93418504952868
lon_hotel =  20.943728942176197
hotel_icon = folium.Icon(icon='star', color='darkgreen', icon_color='white', prefix='glyphicon')
folium.Marker(
    location=[38.93418504952868, 20.943728942176197],
              icon=hotel_icon,
              tooltip='More info here!',
              popup='sleep tight'
             ).add_to(m)
m.zoom_start = 16
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3a0e46aa983429ba9bf8a62cf1eaac8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3a0e46aa983429ba9bf8a62cf1eaac8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3a0e46aa983429ba9bf8a62cf1eaac8 = L.map(
#                 &quot;map_c3a0e46aa983429ba9bf8a62cf1eaac8&quot;,
#                 {
#                     center: [38.956578908379335, 21.02247865318239],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6be77e3094d1bc5f764c78fb34b922cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c3a0e46aa983429ba9bf8a62cf1eaac8);
#
#
#             var marker_46a1f101b5d3bd90bb619e19b7792d8b = L.marker(
#                 [38.956578908379335, 21.02247865318239],
#                 {}
#             ).addTo(map_c3a0e46aa983429ba9bf8a62cf1eaac8);
#
#
#             var icon_79c63b3da253833c184cded13c6550af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_46a1f101b5d3bd90bb619e19b7792d8b.setIcon(icon_79c63b3da253833c184cded13c6550af);
#
#
#         var popup_e79ebca6ebcf0641840a0d834c9f696d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2aa9933209b187f3029c2672e74bb330 = $(`&lt;div id=&quot;html_2aa9933209b187f3029c2672e74bb330&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Κόλπος Αμβρακικού&lt;/div&gt;`)[0];
#             popup_e79ebca6ebcf0641840a0d834c9f696d.setContent(html_2aa9933209b187f3029c2672e74bb330);
#
#
#         marker_46a1f101b5d3bd90bb619e19b7792d8b.bindPopup(popup_e79ebca6ebcf0641840a0d834c9f696d)
#         ;
#
#
#
#
#             marker_46a1f101b5d3bd90bb619e19b7792d8b.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a38c2417d01624825adc5edfad05a662 = L.marker(
#                 [38.93418504952868, 20.943728942176197],
#                 {}
#             ).addTo(map_c3a0e46aa983429ba9bf8a62cf1eaac8);
#
#
#             var icon_5c10e5c17afcbc8c6e506f5fb891ad02 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bed&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a38c2417d01624825adc5edfad05a662.setIcon(icon_5c10e5c17afcbc8c6e506f5fb891ad02);
#
#
#         var popup_a1b641e00d2eb86e29c8c2ef8348c274 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4051541c62a79028fd22f8f1bec545aa = $(`&lt;div id=&quot;html_4051541c62a79028fd22f8f1bec545aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;sleep tight&lt;/div&gt;`)[0];
#             popup_a1b641e00d2eb86e29c8c2ef8348c274.setContent(html_4051541c62a79028fd22f8f1bec545aa);
#
#
#         marker_a38c2417d01624825adc5edfad05a662.bindPopup(popup_a1b641e00d2eb86e29c8c2ef8348c274)
#         ;
#
#
#
#
#             marker_a38c2417d01624825adc5edfad05a662.bindTooltip(
#                 `&lt;div&gt;
#                      More info here!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_37f2d368085b6dbcee2bc6e6a4d20c5d = L.marker(
#                 [38.93418504952868, 20.943728942176197],
#                 {}
#             ).addTo(map_c3a0e46aa983429ba9bf8a62cf1eaac8);
#
#
#             var icon_e1dc2b5b35878a5ec5fd949fde0fd64d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bed&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_37f2d368085b6dbcee2bc6e6a4d20c5d.setIcon(icon_e1dc2b5b35878a5ec5fd949fde0fd64d);
#
#
#         var popup_8e77d901dbd0fa0abb0036c72fa6cd26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_11721727df12e544111a682f53e5995a = $(`&lt;div id=&quot;html_11721727df12e544111a682f53e5995a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;sleep tight&lt;/div&gt;`)[0];
#             popup_8e77d901dbd0fa0abb0036c72fa6cd26.setContent(html_11721727df12e544111a682f53e5995a);
#
#
#         marker_37f2d368085b6dbcee2bc6e6a4d20c5d.bindPopup(popup_8e77d901dbd0fa0abb0036c72fa6cd26)
#         ;
#
#
#
#
#             marker_37f2d368085b6dbcee2bc6e6a4d20c5d.bindToolti

# %%
m = folium.Map(location=[40.48474,22.61200], zoom_start=7
                              
              )
my_icon = folium.Icon(icon='star', color='black', icon_color='red') 

tooltip = "Click Here For More Info"

marker = folium.Marker(
    
    location=[40.48474,22.61200],
    icon=my_icon,
    popup="δέλτα Αξιού, Λουδιά, Αλιάκμονα",
    tooltip=tooltip)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb176a408334eece3cd17b6acfcbf9ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb176a408334eece3cd17b6acfcbf9ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb176a408334eece3cd17b6acfcbf9ca = L.map(
#                 &quot;map_bb176a408334eece3cd17b6acfcbf9ca&quot;,
#                 {
#                     center: [40.48474, 22.612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ab4a8a085cff3e7934c89adef9ef6c4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb176a408334eece3cd17b6acfcbf9ca);
#
#
#             var marker_b6710a5cdb5a47b8c1f9b07ad5088d59 = L.marker(
#                 [40.48474, 22.612],
#                 {}
#             ).addTo(map_bb176a408334eece3cd17b6acfcbf9ca);
#
#
#             var icon_bef87a587453ba20f7e4a78930612c30 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b6710a5cdb5a47b8c1f9b07ad5088d59.setIcon(icon_bef87a587453ba20f7e4a78930612c30);
#
#
#         var popup_9a12f0517bd3eb6620b01c3b30f3c309 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6180179fd2a65ff616307202a877b6dd = $(`&lt;div id=&quot;html_6180179fd2a65ff616307202a877b6dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;δέλτα Αξιού, Λουδιά, Αλιάκμονα&lt;/div&gt;`)[0];
#             popup_9a12f0517bd3eb6620b01c3b30f3c309.setContent(html_6180179fd2a65ff616307202a877b6dd);
#
#
#         marker_b6710a5cdb5a47b8c1f9b07ad5088d59.bindPopup(popup_9a12f0517bd3eb6620b01c3b30f3c309)
#         ;
#
#
#
#
#             marker_b6710a5cdb5a47b8c1f9b07ad5088d59.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# radiofaros's location
lat_faros = 40.51286556068313
lon_faros =  22.747656450045653
faros_icon = folium.Icon(icon='star', color='white', icon_color='black', prefix='glyphicon')
folium.Marker(
    location=[40.51286556068313, 22.747656450045653],
              icon=faros_icon,
              tooltip='More info here!',
              popup='must see'
             ).add_to(m)
m.zoom_start = 16
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb176a408334eece3cd17b6acfcbf9ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb176a408334eece3cd17b6acfcbf9ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb176a408334eece3cd17b6acfcbf9ca = L.map(
#                 &quot;map_bb176a408334eece3cd17b6acfcbf9ca&quot;,
#                 {
#                     center: [40.48474, 22.612],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ab4a8a085cff3e7934c89adef9ef6c4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb176a408334eece3cd17b6acfcbf9ca);
#
#
#             var marker_b6710a5cdb5a47b8c1f9b07ad5088d59 = L.marker(
#                 [40.48474, 22.612],
#                 {}
#             ).addTo(map_bb176a408334eece3cd17b6acfcbf9ca);
#
#
#             var icon_bef87a587453ba20f7e4a78930612c30 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b6710a5cdb5a47b8c1f9b07ad5088d59.setIcon(icon_bef87a587453ba20f7e4a78930612c30);
#
#
#         var popup_9a12f0517bd3eb6620b01c3b30f3c309 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6180179fd2a65ff616307202a877b6dd = $(`&lt;div id=&quot;html_6180179fd2a65ff616307202a877b6dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;δέλτα Αξιού, Λουδιά, Αλιάκμονα&lt;/div&gt;`)[0];
#             popup_9a12f0517bd3eb6620b01c3b30f3c309.setContent(html_6180179fd2a65ff616307202a877b6dd);
#
#
#         marker_b6710a5cdb5a47b8c1f9b07ad5088d59.bindPopup(popup_9a12f0517bd3eb6620b01c3b30f3c309)
#         ;
#
#
#
#
#             marker_b6710a5cdb5a47b8c1f9b07ad5088d59.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a3b3e45d1b42eaafe206d198bf180a8b = L.marker(
#                 [40.51286556068313, 22.747656450045653],
#                 {}
#             ).addTo(map_bb176a408334eece3cd17b6acfcbf9ca);
#
#
#             var icon_5b1b64e0fd76fe8978a91613e546a903 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a3b3e45d1b42eaafe206d198bf180a8b.setIcon(icon_5b1b64e0fd76fe8978a91613e546a903);
#
#
#         var popup_934e763825d06a748a3a714236feb210 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_180864f388d0b8673d391b0c5ed1a047 = $(`&lt;div id=&quot;html_180864f388d0b8673d391b0c5ed1a047&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;must see&lt;/div&gt;`)[0];
#             popup_934e763825d06a748a3a714236feb210.setContent(html_180864f388d0b8673d391b0c5ed1a047);
#
#
#         marker_a3b3e45d1b42eaafe206d198bf180a8b.bindPopup(popup_934e763825d06a748a3a714236feb210)
#         ;
#
#
#
#
#             marker_a3b3e45d1b42eaafe206d198bf180a8b.bindTooltip(
#                 `&lt;div&gt;
#                      More info here!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[40.78073,21.09589], zoom_start=7
                              
              )
my_icon = folium.Icon(icon='star', color='black', icon_color='red') 

tooltip = "Click Here For More Info"

marker = folium.Marker(
    
    location=[40.78073,21.09589],
    icon=my_icon,
    popup="Λίμνη Μικρή Πρέσπα",
    tooltip=tooltip)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83314272170afa529d4890af532f51fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83314272170afa529d4890af532f51fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83314272170afa529d4890af532f51fd = L.map(
#                 &quot;map_83314272170afa529d4890af532f51fd&quot;,
#                 {
#                     center: [40.78073, 21.09589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa962b65d3239e65bac63308098d0f23 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_83314272170afa529d4890af532f51fd);
#
#
#             var marker_5efc7f896c8c23f81a7bb49b111b65a6 = L.marker(
#                 [40.78073, 21.09589],
#                 {}
#             ).addTo(map_83314272170afa529d4890af532f51fd);
#
#
#             var icon_0cea67444f2bc33cb9f36e2a7d898c07 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5efc7f896c8c23f81a7bb49b111b65a6.setIcon(icon_0cea67444f2bc33cb9f36e2a7d898c07);
#
#
#         var popup_45a89a63712860b3cf0287c45b8eaccf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_053280ac7806478e2e53f4de5abe6fc8 = $(`&lt;div id=&quot;html_053280ac7806478e2e53f4de5abe6fc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Λίμνη Μικρή Πρέσπα&lt;/div&gt;`)[0];
#             popup_45a89a63712860b3cf0287c45b8eaccf.setContent(html_053280ac7806478e2e53f4de5abe6fc8);
#
#
#         marker_5efc7f896c8c23f81a7bb49b111b65a6.bindPopup(popup_45a89a63712860b3cf0287c45b8eaccf)
#         ;
#
#
#
#
#             marker_5efc7f896c8c23f81a7bb49b111b65a6.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# cave's location
lat_cave = 40.78306229024468
lon_cave =  21.02893604375494
cave_icon = folium.Icon(icon='star', color='white', icon_color='black', prefix='glyphicon')
folium.Marker(
    location=[40.78306229024468, 21.02893604375494],
              icon=cave_icon,
              tooltip='More info here!',
              popup='με ακούω διπλά διπλά'
             ).add_to(m)
m.zoom_start = 16
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83314272170afa529d4890af532f51fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83314272170afa529d4890af532f51fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83314272170afa529d4890af532f51fd = L.map(
#                 &quot;map_83314272170afa529d4890af532f51fd&quot;,
#                 {
#                     center: [40.78073, 21.09589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa962b65d3239e65bac63308098d0f23 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_83314272170afa529d4890af532f51fd);
#
#
#             var marker_5efc7f896c8c23f81a7bb49b111b65a6 = L.marker(
#                 [40.78073, 21.09589],
#                 {}
#             ).addTo(map_83314272170afa529d4890af532f51fd);
#
#
#             var icon_0cea67444f2bc33cb9f36e2a7d898c07 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5efc7f896c8c23f81a7bb49b111b65a6.setIcon(icon_0cea67444f2bc33cb9f36e2a7d898c07);
#
#
#         var popup_45a89a63712860b3cf0287c45b8eaccf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_053280ac7806478e2e53f4de5abe6fc8 = $(`&lt;div id=&quot;html_053280ac7806478e2e53f4de5abe6fc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Λίμνη Μικρή Πρέσπα&lt;/div&gt;`)[0];
#             popup_45a89a63712860b3cf0287c45b8eaccf.setContent(html_053280ac7806478e2e53f4de5abe6fc8);
#
#
#         marker_5efc7f896c8c23f81a7bb49b111b65a6.bindPopup(popup_45a89a63712860b3cf0287c45b8eaccf)
#         ;
#
#
#
#
#             marker_5efc7f896c8c23f81a7bb49b111b65a6.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_78be08e9ef5d1fa2d7531b36cc8d2200 = L.marker(
#                 [40.78306229024468, 21.02893604375494],
#                 {}
#             ).addTo(map_83314272170afa529d4890af532f51fd);
#
#
#             var icon_1b8067a4787f30d7f4391c227ddfbcd5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_78be08e9ef5d1fa2d7531b36cc8d2200.setIcon(icon_1b8067a4787f30d7f4391c227ddfbcd5);
#
#
#         var popup_54b6452f00101717f6bd427b01877671 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_06dedd0080517575753a512cc2d5196e = $(`&lt;div id=&quot;html_06dedd0080517575753a512cc2d5196e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;με ακούω διπλά διπλά&lt;/div&gt;`)[0];
#             popup_54b6452f00101717f6bd427b01877671.setContent(html_06dedd0080517575753a512cc2d5196e);
#
#
#         marker_78be08e9ef5d1fa2d7531b36cc8d2200.bindPopup(popup_54b6452f00101717f6bd427b01877671)
#         ;
#
#
#
#
#             marker_78be08e9ef5d1fa2d7531b36cc8d2200.bindTooltip(
#                 `&lt;div&gt;
#                      More info here!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[40.68082,23.35907], zoom_start=7
                              
              )
my_icon = folium.Icon(icon='star', color='black', icon_color='red') 

tooltip = "Click Here For More Info"

marker = folium.Marker(
    
    location=[40.68082,23.35907],
    icon=my_icon,
    popup="Λίμνες Βόλβη και Κορώνεια",
    tooltip=tooltip)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74ceda0c2f8daed989cfc8cbf18fbc3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74ceda0c2f8daed989cfc8cbf18fbc3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74ceda0c2f8daed989cfc8cbf18fbc3d = L.map(
#                 &quot;map_74ceda0c2f8daed989cfc8cbf18fbc3d&quot;,
#                 {
#                     center: [40.68082, 23.35907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfd6ca1d433eb0b0e449ec93e38fec02 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var marker_f662228fee0c8b4c7c26aaeb29deec35 = L.marker(
#                 [40.68082, 23.35907],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_c24c82b050b4164703d3b3ee878d9d65 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f662228fee0c8b4c7c26aaeb29deec35.setIcon(icon_c24c82b050b4164703d3b3ee878d9d65);
#
#
#         var popup_d673cbda18efb2c69a28d78c3d5985d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5e36b86902b8f10f5142d5d331e7d52d = $(`&lt;div id=&quot;html_5e36b86902b8f10f5142d5d331e7d52d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Λίμνες Βόλβη και Κορώνεια&lt;/div&gt;`)[0];
#             popup_d673cbda18efb2c69a28d78c3d5985d8.setContent(html_5e36b86902b8f10f5142d5d331e7d52d);
#
#
#         marker_f662228fee0c8b4c7c26aaeb29deec35.bindPopup(popup_d673cbda18efb2c69a28d78c3d5985d8)
#         ;
#
#
#
#
#             marker_f662228fee0c8b4c7c26aaeb29deec35.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# cemetery's location
lat_cem = 40.63463122726221
lon_cem =   23.277421660738444
cem_icon = folium.Icon(icon='star', color='white', icon_color='black', prefix='glyphicon')
folium.Marker(
    location=[40.63463122726221, 23.277421660738444],
              icon=cem_icon,
              tooltip='More info here!',
              popup='RIP'
             ).add_to(m)
m.zoom_start = 16
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74ceda0c2f8daed989cfc8cbf18fbc3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74ceda0c2f8daed989cfc8cbf18fbc3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74ceda0c2f8daed989cfc8cbf18fbc3d = L.map(
#                 &quot;map_74ceda0c2f8daed989cfc8cbf18fbc3d&quot;,
#                 {
#                     center: [40.68082, 23.35907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfd6ca1d433eb0b0e449ec93e38fec02 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var marker_f662228fee0c8b4c7c26aaeb29deec35 = L.marker(
#                 [40.68082, 23.35907],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_c24c82b050b4164703d3b3ee878d9d65 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f662228fee0c8b4c7c26aaeb29deec35.setIcon(icon_c24c82b050b4164703d3b3ee878d9d65);
#
#
#         var popup_d673cbda18efb2c69a28d78c3d5985d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5e36b86902b8f10f5142d5d331e7d52d = $(`&lt;div id=&quot;html_5e36b86902b8f10f5142d5d331e7d52d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Λίμνες Βόλβη και Κορώνεια&lt;/div&gt;`)[0];
#             popup_d673cbda18efb2c69a28d78c3d5985d8.setContent(html_5e36b86902b8f10f5142d5d331e7d52d);
#
#
#         marker_f662228fee0c8b4c7c26aaeb29deec35.bindPopup(popup_d673cbda18efb2c69a28d78c3d5985d8)
#         ;
#
#
#
#
#             marker_f662228fee0c8b4c7c26aaeb29deec35.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_61dcd595f0fc7d19fc7d74101ffd5c43 = L.marker(
#                 [40.63463122726221, 23.277421660738444],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_4a7d3de3a54eff2b6e45256b1d8784c0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_61dcd595f0fc7d19fc7d74101ffd5c43.setIcon(icon_4a7d3de3a54eff2b6e45256b1d8784c0);
#
#
#         var popup_116f3481401041162bbaccbb2793e6e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_12e8e94eff378cf92abf4a65c587aa09 = $(`&lt;div id=&quot;html_12e8e94eff378cf92abf4a65c587aa09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RIP&lt;/div&gt;`)[0];
#             popup_116f3481401041162bbaccbb2793e6e7.setContent(html_12e8e94eff378cf92abf4a65c587aa09);
#
#
#         marker_61dcd595f0fc7d19fc7d74101ffd5c43.bindPopup(popup_116f3481401041162bbaccbb2793e6e7)
#         ;
#
#
#
#
#             marker_61dcd595f0fc7d19fc7d74101ffd5c43.bindTooltip(
#                 `&lt;div&gt;
#                      More info here!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[40.92711,24.75854 ], zoom_start=7
                              
              )
my_icon = folium.Icon(icon='star', color='black', icon_color='red') 

tooltip = "Click Here For More Info"

marker = folium.Marker(
    
    location=[40.92711,24.75854],
    icon=my_icon,
    popup="Δέλτα Νέστου και παρακείμενες λιμνοθάλασσες",
    tooltip=tooltip)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45ac93fe4e5e8e1ec1307ea738d43fe9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45ac93fe4e5e8e1ec1307ea738d43fe9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45ac93fe4e5e8e1ec1307ea738d43fe9 = L.map(
#                 &quot;map_45ac93fe4e5e8e1ec1307ea738d43fe9&quot;,
#                 {
#                     center: [40.92711, 24.75854],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d14cff997cd19206de3ce05471aad28e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_45ac93fe4e5e8e1ec1307ea738d43fe9);
#
#
#             var marker_54242c2bb341ff970f8f910ad741c266 = L.marker(
#                 [40.92711, 24.75854],
#                 {}
#             ).addTo(map_45ac93fe4e5e8e1ec1307ea738d43fe9);
#
#
#             var icon_15617d4d07fb61e875cd72d967bcc8bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_54242c2bb341ff970f8f910ad741c266.setIcon(icon_15617d4d07fb61e875cd72d967bcc8bc);
#
#
#         var popup_940dc49f0afa3c3c8018d95f5da37ee0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ad2edb7b9ff8f3c5efd0aa35955abcf6 = $(`&lt;div id=&quot;html_ad2edb7b9ff8f3c5efd0aa35955abcf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Δέλτα Νέστου και παρακείμενες λιμνοθάλασσες&lt;/div&gt;`)[0];
#             popup_940dc49f0afa3c3c8018d95f5da37ee0.setContent(html_ad2edb7b9ff8f3c5efd0aa35955abcf6);
#
#
#         marker_54242c2bb341ff970f8f910ad741c266.bindPopup(popup_940dc49f0afa3c3c8018d95f5da37ee0)
#         ;
#
#
#
#
#             marker_54242c2bb341ff970f8f910ad741c266.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# καφέ μουσείο's location
lat_coffee = 41.00807188573541
lon_coffee =  25.123157219855
coffee_icon = folium.Icon(icon='star', color='white', icon_color='black', prefix='glyphicon')
folium.Marker(
    location=[41.00807188573541, 25.1231572198559],
              icon=coffee_icon,
              tooltip='More info here!',
              popup='coffee coffee starting at 9.00 '
             ).add_to(m)
m.zoom_start = 16
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74ceda0c2f8daed989cfc8cbf18fbc3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74ceda0c2f8daed989cfc8cbf18fbc3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74ceda0c2f8daed989cfc8cbf18fbc3d = L.map(
#                 &quot;map_74ceda0c2f8daed989cfc8cbf18fbc3d&quot;,
#                 {
#                     center: [40.68082, 23.35907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfd6ca1d433eb0b0e449ec93e38fec02 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var marker_f662228fee0c8b4c7c26aaeb29deec35 = L.marker(
#                 [40.68082, 23.35907],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_c24c82b050b4164703d3b3ee878d9d65 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f662228fee0c8b4c7c26aaeb29deec35.setIcon(icon_c24c82b050b4164703d3b3ee878d9d65);
#
#
#         var popup_d673cbda18efb2c69a28d78c3d5985d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5e36b86902b8f10f5142d5d331e7d52d = $(`&lt;div id=&quot;html_5e36b86902b8f10f5142d5d331e7d52d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Λίμνες Βόλβη και Κορώνεια&lt;/div&gt;`)[0];
#             popup_d673cbda18efb2c69a28d78c3d5985d8.setContent(html_5e36b86902b8f10f5142d5d331e7d52d);
#
#
#         marker_f662228fee0c8b4c7c26aaeb29deec35.bindPopup(popup_d673cbda18efb2c69a28d78c3d5985d8)
#         ;
#
#
#
#
#             marker_f662228fee0c8b4c7c26aaeb29deec35.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_61dcd595f0fc7d19fc7d74101ffd5c43 = L.marker(
#                 [40.63463122726221, 23.277421660738444],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_4a7d3de3a54eff2b6e45256b1d8784c0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_61dcd595f0fc7d19fc7d74101ffd5c43.setIcon(icon_4a7d3de3a54eff2b6e45256b1d8784c0);
#
#
#         var popup_116f3481401041162bbaccbb2793e6e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_12e8e94eff378cf92abf4a65c587aa09 = $(`&lt;div id=&quot;html_12e8e94eff378cf92abf4a65c587aa09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RIP&lt;/div&gt;`)[0];
#             popup_116f3481401041162bbaccbb2793e6e7.setContent(html_12e8e94eff378cf92abf4a65c587aa09);
#
#
#         marker_61dcd595f0fc7d19fc7d74101ffd5c43.bindPopup(popup_116f3481401041162bbaccbb2793e6e7)
#         ;
#
#
#
#
#             marker_61dcd595f0fc7d19fc7d74101ffd5c43.bindTooltip(
#                 `&lt;div&gt;
#                      More info here!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_555bfecbf0260310c50af09da6d6a515 = L.marker(
#                 [41.00807188573541, 25.1231572198559],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_aa6f9bea022ab0579964d6b3a70e62b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_555bfecbf0260310c50af09da6d6a515.setIcon(icon_aa6f9bea022ab0579964d6b3a70e62b7);
#
#
#         var popup_6dd511eb8929b7dab7f2e93b3940e081 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_367947b964b1ca890bbcdfd9f7c256b4 = $(`&lt;div id=&quot;html_367947b964b1ca890bbcdfd9f7c256b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;coffee coffee starting at 9.00 &lt;/div&gt;`)[0];
#             popup_6dd511eb8929b7dab7f2e93b3940e081.setContent(html_367947b964b1ca890bbcdfd9f7c256b4);
#
#
#         marker_555bfecbf0260310c50af09da6d6a515.bindPopup(popup_6dd511eb8929b7dab7f2e93b3940e081)
#         ;
#
#
#
#
#             marker_555bfecbf0260310c50af09da6d6a515.bindTooltip(
#                 `&lt

# %%
m = folium.Map(location=[40.96437,25.29010 ], zoom_start=7
                              
              )
my_icon = folium.Icon(icon='star', color='black', icon_color='red') 

tooltip = "Click Here For More Info"

marker = folium.Marker(
    
    location=[40.96437,25.29010],
    icon=my_icon,
    popup="Λίμνη Βιστονίδα, Πόρτο-Λάγος, Λίμνη Ισμαρίδα και παρακείμενες λιμνοθάλασσες",
    tooltip=tooltip)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5701e7b72bbe6a123552901c7d3e7851 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5701e7b72bbe6a123552901c7d3e7851&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5701e7b72bbe6a123552901c7d3e7851 = L.map(
#                 &quot;map_5701e7b72bbe6a123552901c7d3e7851&quot;,
#                 {
#                     center: [40.96437, 25.2901],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_793d4604248634f795ff836dd409d592 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5701e7b72bbe6a123552901c7d3e7851);
#
#
#             var marker_8bb4bbd8d36ab54e44b78b36f8f3d344 = L.marker(
#                 [40.96437, 25.2901],
#                 {}
#             ).addTo(map_5701e7b72bbe6a123552901c7d3e7851);
#
#
#             var icon_513f582f0cc8f091a3ad2527e6955054 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8bb4bbd8d36ab54e44b78b36f8f3d344.setIcon(icon_513f582f0cc8f091a3ad2527e6955054);
#
#
#         var popup_4aa2aaa1fe3b7b9a592c51625d51f900 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5f4e23d1fe11ede951b0ccf5fea52e37 = $(`&lt;div id=&quot;html_5f4e23d1fe11ede951b0ccf5fea52e37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Λίμνη Βιστονίδα, Πόρτο-Λάγος, Λίμνη Ισμαρίδα και παρακείμενες λιμνοθάλασσες&lt;/div&gt;`)[0];
#             popup_4aa2aaa1fe3b7b9a592c51625d51f900.setContent(html_5f4e23d1fe11ede951b0ccf5fea52e37);
#
#
#         marker_8bb4bbd8d36ab54e44b78b36f8f3d344.bindPopup(popup_4aa2aaa1fe3b7b9a592c51625d51f900)
#         ;
#
#
#
#
#             marker_8bb4bbd8d36ab54e44b78b36f8f3d344.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# hotel's location
lat_hotel = 41.006757190689115
lon_hotel =  25.11565744019954
hotel_icon = folium.Icon(icon='star', color='white', icon_color='black', prefix='glyphicon')
folium.Marker(
    location=[41.006757190689115, 25.11565744019954],
              icon=hotel_icon,
              tooltip='More info here!',
              popup='goodnight '
             ).add_to(m)
m.zoom_start = 16
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74ceda0c2f8daed989cfc8cbf18fbc3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74ceda0c2f8daed989cfc8cbf18fbc3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74ceda0c2f8daed989cfc8cbf18fbc3d = L.map(
#                 &quot;map_74ceda0c2f8daed989cfc8cbf18fbc3d&quot;,
#                 {
#                     center: [40.68082, 23.35907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfd6ca1d433eb0b0e449ec93e38fec02 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var marker_f662228fee0c8b4c7c26aaeb29deec35 = L.marker(
#                 [40.68082, 23.35907],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_c24c82b050b4164703d3b3ee878d9d65 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f662228fee0c8b4c7c26aaeb29deec35.setIcon(icon_c24c82b050b4164703d3b3ee878d9d65);
#
#
#         var popup_d673cbda18efb2c69a28d78c3d5985d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5e36b86902b8f10f5142d5d331e7d52d = $(`&lt;div id=&quot;html_5e36b86902b8f10f5142d5d331e7d52d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Λίμνες Βόλβη και Κορώνεια&lt;/div&gt;`)[0];
#             popup_d673cbda18efb2c69a28d78c3d5985d8.setContent(html_5e36b86902b8f10f5142d5d331e7d52d);
#
#
#         marker_f662228fee0c8b4c7c26aaeb29deec35.bindPopup(popup_d673cbda18efb2c69a28d78c3d5985d8)
#         ;
#
#
#
#
#             marker_f662228fee0c8b4c7c26aaeb29deec35.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_61dcd595f0fc7d19fc7d74101ffd5c43 = L.marker(
#                 [40.63463122726221, 23.277421660738444],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_4a7d3de3a54eff2b6e45256b1d8784c0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_61dcd595f0fc7d19fc7d74101ffd5c43.setIcon(icon_4a7d3de3a54eff2b6e45256b1d8784c0);
#
#
#         var popup_116f3481401041162bbaccbb2793e6e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_12e8e94eff378cf92abf4a65c587aa09 = $(`&lt;div id=&quot;html_12e8e94eff378cf92abf4a65c587aa09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RIP&lt;/div&gt;`)[0];
#             popup_116f3481401041162bbaccbb2793e6e7.setContent(html_12e8e94eff378cf92abf4a65c587aa09);
#
#
#         marker_61dcd595f0fc7d19fc7d74101ffd5c43.bindPopup(popup_116f3481401041162bbaccbb2793e6e7)
#         ;
#
#
#
#
#             marker_61dcd595f0fc7d19fc7d74101ffd5c43.bindTooltip(
#                 `&lt;div&gt;
#                      More info here!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_555bfecbf0260310c50af09da6d6a515 = L.marker(
#                 [41.00807188573541, 25.1231572198559],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_aa6f9bea022ab0579964d6b3a70e62b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_555bfecbf0260310c50af09da6d6a515.setIcon(icon_aa6f9bea022ab0579964d6b3a70e62b7);
#
#
#         var popup_6dd511eb8929b7dab7f2e93b3940e081 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_367947b964b1ca890bbcdfd9f7c256b4 = $(`&lt;div id=&quot;html_367947b964b1ca890bbcdfd9f7c256b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;coffee coffee starting at 9.00 &lt;/div&gt;`)[0];
#             popup_6dd511eb8929b7dab7f2e93b3940e081.setContent(html_367947b964b1ca890bbcdfd9f7c256b4);
#
#
#         marker_555bfecbf0260310c50af09da6d6a515.bindPopup(popup_6dd511eb8929b7dab7f2e93b3940e081)
#         ;
#
#
#
#
#             marker_555bfecbf0260310c50af09da6d6a515.bindTooltip(
#                 `&lt

# %%
m = folium.Map(location=[40.79825,26.03717 ], zoom_start=7
                              
              )
my_icon = folium.Icon(icon='star', color='black', icon_color='red') 

tooltip = "Click Here For More Info"

marker = folium.Marker(
    
    location=[40.79825,26.03717],
    icon=my_icon,
    popup="Δέλτα Έβρου",
    tooltip=tooltip)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93fc8899d8c83bc645f3005e39dc57b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93fc8899d8c83bc645f3005e39dc57b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93fc8899d8c83bc645f3005e39dc57b2 = L.map(
#                 &quot;map_93fc8899d8c83bc645f3005e39dc57b2&quot;,
#                 {
#                     center: [40.79825, 26.03717],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f94a0c28a1ad9575e625ceb79db2cc50 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93fc8899d8c83bc645f3005e39dc57b2);
#
#
#             var marker_a0420f2214fdd6a7137dfe9a42c18d2f = L.marker(
#                 [40.79825, 26.03717],
#                 {}
#             ).addTo(map_93fc8899d8c83bc645f3005e39dc57b2);
#
#
#             var icon_3f927913a462dff07dce6d7f06cb5b65 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a0420f2214fdd6a7137dfe9a42c18d2f.setIcon(icon_3f927913a462dff07dce6d7f06cb5b65);
#
#
#         var popup_a300984a4d4eb4f37841e965cba8940f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_959158a93204d096b2bf0d234446e3a1 = $(`&lt;div id=&quot;html_959158a93204d096b2bf0d234446e3a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Δέλτα Έβρου&lt;/div&gt;`)[0];
#             popup_a300984a4d4eb4f37841e965cba8940f.setContent(html_959158a93204d096b2bf0d234446e3a1);
#
#
#         marker_a0420f2214fdd6a7137dfe9a42c18d2f.bindPopup(popup_a300984a4d4eb4f37841e965cba8940f)
#         ;
#
#
#
#
#             marker_a0420f2214fdd6a7137dfe9a42c18d2f.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# agio_sotiras_beach's location
lat_beach = 40.82252606789282
lon_beach = 25.988519892677118
beach_icon = folium.Icon(icon='glass', color='blue', icon_color='white', prefix='glyphicon')
folium.Marker(
    location=[40.82252606789282, 25.988519892677118],
              icon=beach_icon,
              tooltip='More info here!',
              popup='swim all day'
             ).add_to(m)
m.zoom_start = 16
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74ceda0c2f8daed989cfc8cbf18fbc3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74ceda0c2f8daed989cfc8cbf18fbc3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74ceda0c2f8daed989cfc8cbf18fbc3d = L.map(
#                 &quot;map_74ceda0c2f8daed989cfc8cbf18fbc3d&quot;,
#                 {
#                     center: [40.68082, 23.35907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfd6ca1d433eb0b0e449ec93e38fec02 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var marker_f662228fee0c8b4c7c26aaeb29deec35 = L.marker(
#                 [40.68082, 23.35907],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_c24c82b050b4164703d3b3ee878d9d65 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f662228fee0c8b4c7c26aaeb29deec35.setIcon(icon_c24c82b050b4164703d3b3ee878d9d65);
#
#
#         var popup_d673cbda18efb2c69a28d78c3d5985d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5e36b86902b8f10f5142d5d331e7d52d = $(`&lt;div id=&quot;html_5e36b86902b8f10f5142d5d331e7d52d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Λίμνες Βόλβη και Κορώνεια&lt;/div&gt;`)[0];
#             popup_d673cbda18efb2c69a28d78c3d5985d8.setContent(html_5e36b86902b8f10f5142d5d331e7d52d);
#
#
#         marker_f662228fee0c8b4c7c26aaeb29deec35.bindPopup(popup_d673cbda18efb2c69a28d78c3d5985d8)
#         ;
#
#
#
#
#             marker_f662228fee0c8b4c7c26aaeb29deec35.bindTooltip(
#                 `&lt;div&gt;
#                      Click Here For More Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_61dcd595f0fc7d19fc7d74101ffd5c43 = L.marker(
#                 [40.63463122726221, 23.277421660738444],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_4a7d3de3a54eff2b6e45256b1d8784c0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_61dcd595f0fc7d19fc7d74101ffd5c43.setIcon(icon_4a7d3de3a54eff2b6e45256b1d8784c0);
#
#
#         var popup_116f3481401041162bbaccbb2793e6e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_12e8e94eff378cf92abf4a65c587aa09 = $(`&lt;div id=&quot;html_12e8e94eff378cf92abf4a65c587aa09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RIP&lt;/div&gt;`)[0];
#             popup_116f3481401041162bbaccbb2793e6e7.setContent(html_12e8e94eff378cf92abf4a65c587aa09);
#
#
#         marker_61dcd595f0fc7d19fc7d74101ffd5c43.bindPopup(popup_116f3481401041162bbaccbb2793e6e7)
#         ;
#
#
#
#
#             marker_61dcd595f0fc7d19fc7d74101ffd5c43.bindTooltip(
#                 `&lt;div&gt;
#                      More info here!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_555bfecbf0260310c50af09da6d6a515 = L.marker(
#                 [41.00807188573541, 25.1231572198559],
#                 {}
#             ).addTo(map_74ceda0c2f8daed989cfc8cbf18fbc3d);
#
#
#             var icon_aa6f9bea022ab0579964d6b3a70e62b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_555bfecbf0260310c50af09da6d6a515.setIcon(icon_aa6f9bea022ab0579964d6b3a70e62b7);
#
#
#         var popup_6dd511eb8929b7dab7f2e93b3940e081 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_367947b964b1ca890bbcdfd9f7c256b4 = $(`&lt;div id=&quot;html_367947b964b1ca890bbcdfd9f7c256b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;coffee coffee starting at 9.00 &lt;/div&gt;`)[0];
#             popup_6dd511eb8929b7dab7f2e93b3940e081.setContent(html_367947b964b1ca890bbcdfd9f7c256b4);
#
#
#         marker_555bfecbf0260310c50af09da6d6a515.bindPopup(popup_6dd511eb8929b7dab7f2e93b3940e081)
#         ;
#
#
#
#
#             marker_555bfecbf0260310c50af09da6d6a515.bindTooltip(
#                 `&lt

# %%
mymap.save('interactive_map.html')
del(mymap)
